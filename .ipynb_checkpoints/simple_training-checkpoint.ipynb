# %% [markdown]
# # Data

# %%
import logging 
import numpy as np
import importlib
import pandas as pd
from os.path import join
from data.data_access import Data
from preprocessing import pre
from utils.logs import set_logging
from config_path import ENH_LOG_PATH

params_file = 'train/params/P1000/pnet/onsplit_average_reg_10_tanh_large_testing.py'

log_dir = join(ENH_LOG_PATH, 'log')
log_dir = log_dir
set_logging(log_dir)
# Out:
# setting logs

# %%
loader = importlib.machinery.SourceFileLoader('params', params_file)
params = loader.load_module()
# Out:
# 2023-11-29 18:20:45.594838: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-29 18:20:49.404002: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-29 18:20:49.404175: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-29 18:20:49.736027: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-29 18:20:50.650698: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-29 18:20:50.665802: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-29 18:20:54.635347: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
params
# Out:
# <module 'params' from 'train/params/P1000/pnet/onsplit_average_reg_10_tanh_large_testing.py'>

# %%
data = Data(**params.data[0])
# Out:
# loading enh_vs_genes
# loading data from /PROJECTS/Sally/PNET_py3_enh_gene/_database/enh_vs_genes/Enh_vs_Genes_matrix_number.txt,
# (73347, 30781)
# loading response from Enh_vs_Genes_interactions_1Oct.txt
# loaded data 73347 samples, 30781 variables, 73347 responses
# 30781

# %%
x_train, x_validate_, x_test_, y_train, y_validate_, y_test_, info_train, info_validate_, info_test_, cols = data.get_train_validate_test()

# %%
import csv

info_t = info_test_

# %%
print("x_train:", x_train.shape)
print("x_train:", y_train.shape)

print("x_validate_:", x_validate_.shape)
print("y_validate_:", y_validate_.shape)

print("x_test:", x_test_.shape)
print("y_test:", y_test_.shape)

print("columns:", len(cols))
# Out:
# x_train: (58677, 30781)
# x_train: (58677,)
# x_validate_: (7335, 30781)
# y_validate_: (7335,)
# x_test: (7335, 30781)
# y_test: (7335,)
# columns: 30781

# %% [markdown]
# # Model

# %%
from copy import deepcopy
from model import nn

# %%
model_params_ = deepcopy(params.models[0])

# %%
model = nn.Model(**model_params_['params'])
# Out:
# class_weight None

# %%
history = model.fit(x_train, y_train, x_validate_, y_validate_)
# Out:
# {'id': 'ALL', 'type': 'prostate_paper', 'params': {'data_type': 'enh_vs_genes', 'drop_AR': False, 'mut_binary': True, 'balanced_data': False, 'combine_type': 'union', 'use_coding_genes_only': True, 'selected_genes': None, 'training_split': 0}}
# n_hidden_layers 2
# loading enh_vs_genes
# loading data from /PROJECTS/Sally/PNET_py3_enh_gene/_database/enh_vs_genes/Enh_vs_Genes_matrix_number.txt,
# loading from memory cached_data
# (73347, 30781)
# loading from memory cached_data
# loaded data 73347 samples, 30781 variables, 73347 responses
# 30781
# (73347, 30781)
# (73347,)
# (73347,)
# (30781,)
# x shape (73347, 30781) , y shape (73347,) info (73347,) genes (30781,)
# x shape (73347, 30781) , y shape (73347,) info (73347,) genes (30781,)
# input dimension 30781 self.units 30781
# n_inputs_per_node 1.0
# self.kernel_initializer <keras.src.regularizers.L2 object at 0x7fc86150cd90> <keras.src.initializers.initializers.LecunUniform object at 0x7fc847605dd0> <keras.src.regularizers.L2 object at 0x7fc86150cd90>
# 2023-11-29 18:36:46.097704: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:274] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# input dimensions (None, 30781)
# layer # 0
# pathways 146
# genes 10621
# filtered_map (30781, 0)
# filtered_map (30781, 0)
# filtered_map (30781, 0)
# layer 0 , # of edges  0.0
# layer # 1
# pathways 26
# genes 147
# filtered_map (146, 0)
# filtered_map (146, 0)
# filtered_map (146, 0)
# layer 1 , # of edges  147.0
# layer # 2
# pathways 1
# genes 26
# filtered_map (26, 0)
# filtered_map (26, 0)
# filtered_map (26, 0)
# layer 2 , # of edges  26.0
# original dropout [0.5, 0.1, 0.1, 0.1]
# dropout [1, 2] [0.5, 0.1, 0.1, 0.1] [0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001]
# n_genes, n_pathways 30781 146
# layer 0, dropout  0.1 w_reg 0.001
# n_genes, n_pathways 146 26
# layer 1, dropout  0.1 w_reg 0.001
# Compiling...
# loss_weights [2, 7, 20, 54, 148, 400]
# done compiling
#   - 0 inputs [(None, 30781)]
#   - 1 h0 (None, 30781)
#   - 2 dropout_0 (None, 30781)
#   - 3 h1 (None, 146)
#   - 4 dropout_1 (None, 146)
#   - 5 h2 (None, 26)
#   - 6 o_linear1 (None, 1)
#   - 7 o_linear2 (None, 1)
#   - 8 o_linear3 (None, 1)
#   - 9 o1 (None, 1)
#   - 10 o2 (None, 1)
#   - 11 o3 (None, 1)
# [<keras.src.engine.input_layer.InputLayer object at 0x7fc86184bd50>, <model.layers_custom.Diagonal object at 0x7fc86150e150>, <keras.src.layers.regularization.dropout.Dropout object at 0x7fc7a0c585d0>, <model.layers_custom.SparseTF object at 0x7fc854c06a10>, <keras.src.layers.regularization.dropout.Dropout object at 0x7fc854c0d0d0>, <model.layers_custom.SparseTF object at 0x7fc86005c150>, <keras.src.layers.core.dense.Dense object at 0x7fc85fe29f90>, <keras.src.layers.core.dense.Dense object at 0x7fc854c0f090>, <keras.src.layers.core.dense.Dense object at 0x7fc854c08d90>, <keras.src.layers.core.activation.Activation object at 0x7fc63daa1710>, <keras.src.layers.core.activation.Activation object at 0x7fc854c0c2d0>, <keras.src.layers.core.activation.Activation object at 0x7fc854c08650>]
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  inputs (InputLayer)         [(None, 30781)]              0         []
#
#  h0 (Diagonal)               (None, 30781)                61562     ['inputs[0][0]']
#
#  dropout_0 (Dropout)         (None, 30781)                0         ['h0[0][0]']
#
#  h1 (SparseTF)               (None, 146)                  146       ['dropout_0[0][0]']
#
#  dropout_1 (Dropout)         (None, 146)                  0         ['h1[0][0]']
#
#  h2 (SparseTF)               (None, 26)                   173       ['dropout_1[0][0]']
#
#  o_linear1 (Dense)           (None, 1)                    30782     ['h0[0][0]']
#
#  o_linear2 (Dense)           (None, 1)                    147       ['h1[0][0]']
#
#  o_linear3 (Dense)           (None, 1)                    27        ['h2[0][0]']
#
#  o1 (Activation)             (None, 1)                    0         ['o_linear1[0][0]']
#
#  o2 (Activation)             (None, 1)                    0         ['o_linear2[0][0]']
#
#  o3 (Activation)             (None, 1)                    0         ['o_linear3[0][0]']
#
# ==================================================================================================
# Total params: 92837 (362.64 KB)
# Trainable params: 92837 (362.64 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# None
# # of trainable params of the model is 92837
# start fitting
# class_weight None
# ##################################################
# {'_self_setattr_tracking': True, '_obj_reference_counts_dict': ObjectIdentityDictionary({<_ObjectIdentityWrapper wrapping <keras.src.saving.serialization_lib.Config object at 0x7fc854c04510>>: 1, <_ObjectIdentityWrapper wrapping <keras.src.optimizers.adam.Adam object at 0x7fc854c04550>>: 1, <_ObjectIdentityWrapper wrapping <keras.src.engine.compile_utils.LossesContainer object at 0x7fc63a4ea750>>: 1, <_ObjectIdentityWrapper wrapping <keras.src.engine.compile_utils.MetricsContainer object at 0x7fc63a489a10>>: 1, <_ObjectIdentityWrapper wrapping 0>: 1, <_ObjectIdentityWrapper wrapping True>: 1, <_ObjectIdentityWrapper wrapping ListWrapper(['binary_crossentropy', 'binary_crossentropy', 'binary_crossentropy'])>: 1}), '_auto_get_config': False, '_is_model_for_instrumentation': True, '_instrumented_keras_api': True, '_instrumented_keras_layer_class': False, '_instrumented_keras_model_class': True, '_trainable': True, '_stateful': False, 'built': True, '_input_spec': None, '_build_input_shape': TensorShape([None, 30781]), '_saved_model_inputs_spec': TensorSpec(shape=(None, 30781), dtype=tf.float32, name='inputs'), '_saved_model_arg_spec': ([TensorSpec(shape=(None, 30781), dtype=tf.float32, name='inputs')], {}), '_supports_masking': True, '_name': 'model', '_activity_regularizer': None, '_trainable_weights': [], '_non_trainable_weights': [], '_updates': [], '_thread_local': <_thread._local object at 0x7fc8476cc590>, '_callable_losses': [], '_losses': [], '_metrics': [], '_metrics_lock': <unlocked _thread.lock object at 0x7fc8614512c0>, '_dtype_policy': <Policy "float32">, '_compute_dtype_object': tf.float32, '_autocast': False, '_self_tracked_trackables': [<keras.src.engine.input_layer.InputLayer object at 0x7fc86184bd50>, <model.layers_custom.Diagonal object at 0x7fc86150e150>, <keras.src.layers.regularization.dropout.Dropout object at 0x7fc7a0c585d0>, <model.layers_custom.SparseTF object at 0x7fc854c06a10>, <keras.src.layers.regularization.dropout.Dropout object at 0x7fc854c0d0d0>, <model.layers_custom.SparseTF object at 0x7fc86005c150>, <keras.src.layers.core.dense.Dense object at 0x7fc85fe29f90>, <keras.src.layers.core.dense.Dense object at 0x7fc854c0f090>, <keras.src.layers.core.dense.Dense object at 0x7fc854c08d90>, <keras.src.layers.core.activation.Activation object at 0x7fc63daa1710>, <keras.src.layers.core.activation.Activation object at 0x7fc854c0c2d0>, <keras.src.layers.core.activation.Activation object at 0x7fc854c08650>, ListWrapper(['binary_crossentropy', 'binary_crossentropy', 'binary_crossentropy'])], '_inbound_nodes_value': [], '_outbound_nodes_value': [], '_call_spec': <keras.src.utils.layer_utils.CallFunctionSpec object at 0x7fc8600182d0>, '_dynamic': False, '_initial_weights': None, '_auto_track_sub_layers': True, '_preserve_input_structure_in_config': False, '_name_scope_on_declaration': '', '_captured_weight_regularizer': [], '_is_graph_network': True, 'inputs': [<KerasTensor: shape=(None, 30781) dtype=float32 (created by layer 'inputs')>], 'outputs': [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'o1')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'o2')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'o3')>], 'input_names': ['inputs'], 'output_names': ['o1', 'o2', 'o3'], 'stop_training': False, 'history': None, '_compute_output_and_mask_jointly': True, '_distribution_strategy': None, '_distribute_reduction_method': None, '_cluster_coordinator': None, 'train_function': None, 'test_function': None, 'predict_function': None, 'train_tf_function': None, '_compiled_trainable_state': <WeakKeyDictionary at 0x7fc854c0f0d0>, '_training_state': None, '_self_unconditional_checkpoint_dependencies': [TrackableReference(name=optimizer, ref=<keras.src.optimizers.adam.Adam object at 0x7fc854c04550>), TrackableReference(name=loss, ref=ListWrapper(['binary_crossentropy', 'binary_crossentropy', 'binary_crossentropy']))], '_self_unconditional_dependency_names': {'optimizer': <keras.s ...
# ##################################################
# 3
# ##################################################
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  inputs (InputLayer)         [(None, 30781)]              0         []
#
#  h0 (Diagonal)               (None, 30781)                61562     ['inputs[0][0]']
#
#  dropout_0 (Dropout)         (None, 30781)                0         ['h0[0][0]']
#
#  h1 (SparseTF)               (None, 146)                  146       ['dropout_0[0][0]']
#
#  dropout_1 (Dropout)         (None, 146)                  0         ['h1[0][0]']
#
#  h2 (SparseTF)               (None, 26)                   173       ['dropout_1[0][0]']
#
#  o_linear1 (Dense)           (None, 1)                    30782     ['h0[0][0]']
#
#  o_linear2 (Dense)           (None, 1)                    147       ['h1[0][0]']
#
#  o_linear3 (Dense)           (None, 1)                    27        ['h2[0][0]']
#
#  o1 (Activation)             (None, 1)                    0         ['o_linear1[0][0]']
#
#  o2 (Activation)             (None, 1)                    0         ['o_linear2[0][0]']
#
#  o3 (Activation)             (None, 1)                    0         ['o_linear3[0][0]']
#
# ==================================================================================================
# Total params: 92837 (362.64 KB)
# Trainable params: 92837 (362.64 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# None
# 2023-11-29 18:37:24.733241: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 14449093896 exceeds 10% of free system memory.
# Epoch 1: LearningRateScheduler setting learning rate to 0.001.
# Epoch 1/100
# input dimensions (None, 30781)
# input dimensions (None, 30781)
# input dimensions (None, 30781)
# input dimensions (None, 30781)
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 103s - loss: 19.9343 - o1_loss: 0.6040 - o2_loss: 0.6932 - o3_loss: 0.6932 - o1_f1: 0.7821 - o2_f1: 0.0910 - o3_f1: 0.1247 - val_loss: 19.7951 - val_o1_loss: 0.5343 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.4902 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 0.0010 - 103s/epoch - 176ms/step
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.001.
# Epoch 2/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 39s - loss: 19.6991 - o1_loss: 0.4827 - o2_loss: 0.6932 - o3_loss: 0.6932 - o1_f1: 0.8195 - o2_f1: 0.0631 - o3_f1: 0.0642 - val_loss: 19.6510 - val_o1_loss: 0.4550 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.4838 - val_o2_f1: 0.6002 - val_o3_f1: 0.6002 - lr: 0.0010 - 39s/epoch - 66ms/step
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.001.
# Epoch 3/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 9s - loss: 19.6072 - o1_loss: 0.4292 - o2_loss: 0.6932 - o3_loss: 0.6932 - o1_f1: 0.8204 - o2_f1: 0.1902 - o3_f1: 0.1969 - val_loss: 19.5922 - val_o1_loss: 0.4188 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.4914 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 0.0010 - 9s/epoch - 16ms/step
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.001.
# Epoch 4/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 33s - loss: 19.5698 - o1_loss: 0.4048 - o2_loss: 0.6932 - o3_loss: 0.6932 - o1_f1: 0.8229 - o2_f1: 0.1038 - o3_f1: 0.1038 - val_loss: 19.5678 - val_o1_loss: 0.4016 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.4967 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 0.0010 - 33s/epoch - 56ms/step
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.001.
# Epoch 5/100
# 230/230 [==============================] - 1s 5ms/step
# 587/587 - 32s - loss: 19.5491 - o1_loss: 0.3907 - o2_loss: 0.6932 - o3_loss: 0.6932 - o1_f1: 0.8254 - o2_f1: 0.1019 - o3_f1: 0.1019 - val_loss: 19.5514 - val_o1_loss: 0.3907 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5030 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 0.0010 - 32s/epoch - 54ms/step
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.001.
# Epoch 6/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 10s - loss: 19.5379 - o1_loss: 0.3824 - o2_loss: 0.6932 - o3_loss: 0.6932 - o1_f1: 0.8296 - o2_f1: 0.1186 - o3_f1: 0.0938 - val_loss: 19.5430 - val_o1_loss: 0.3844 - val_o2_loss: 0.6932 - val_o3_loss: 0.6931 - val_o1_f1: 0.4973 - val_o2_f1: 0.6002 - val_o3_f1: 0.0000e+00 - lr: 0.0010 - 10s/epoch - 18ms/step
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.001.
# Epoch 7/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 10s - loss: 19.5286 - o1_loss: 0.3763 - o2_loss: 0.6932 - o3_loss: 0.6932 - o1_f1: 0.8332 - o2_f1: 0.1497 - o3_f1: 0.0675 - val_loss: 19.5344 - val_o1_loss: 0.3790 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.4974 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 0.0010 - 10s/epoch - 18ms/step
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.001.
# Epoch 8/100
# 230/230 [==============================] - 1s 5ms/step
# 587/587 - 9s - loss: 19.5193 - o1_loss: 0.3710 - o2_loss: 0.6931 - o3_loss: 0.6931 - o1_f1: 0.8377 - o2_f1: 0.2131 - o3_f1: 0.1775 - val_loss: 19.5375 - val_o1_loss: 0.3792 - val_o2_loss: 0.6932 - val_o3_loss: 0.6932 - val_o1_f1: 0.5188 - val_o2_f1: 0.6002 - val_o3_f1: 0.6002 - lr: 0.0010 - 9s/epoch - 16ms/step
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.001.
# Epoch 9/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 10s - loss: 19.5142 - o1_loss: 0.3675 - o2_loss: 0.6932 - o3_loss: 0.6932 - o1_f1: 0.8415 - o2_f1: 0.1129 - o3_f1: 0.1422 - val_loss: 19.5216 - val_o1_loss: 0.3714 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5148 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.6002 - lr: 0.0010 - 10s/epoch - 16ms/step
#
# Epoch 10: LearningRateScheduler setting learning rate to 0.001.
# Epoch 10/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 10s - loss: 19.5081 - o1_loss: 0.3642 - o2_loss: 0.6932 - o3_loss: 0.6932 - o1_f1: 0.8460 - o2_f1: 0.1365 - o3_f1: 0.1362 - val_loss: 19.5178 - val_o1_loss: 0.3691 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.4969 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 0.0010 - 10s/epoch - 16ms/step
#
# Epoch 11: LearningRateScheduler setting learning rate to 0.001.
# Epoch 11/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 10s - loss: 19.5030 - o1_loss: 0.3614 - o2_loss: 0.6932 - o3_loss: 0.6932 - o1_f1: 0.8480 - o2_f1: 0.1043 - o3_f1: 0.0928 - val_loss: 19.5106 - val_o1_loss: 0.3655 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5136 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 0.0010 - 10s/epoch - 18ms/step
#
# Epoch 12: LearningRateScheduler setting learning rate to 0.001.
# Epoch 12/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 10s - loss: 19.4986 - o1_loss: 0.3591 - o2_loss: 0.6932 - o3_loss: 0.6932 - o1_f1: 0.8500 - o2_f1: 0.1573 - o3_f1: 0.1338 - val_loss: 19.5454 - val_o1_loss: 0.3822 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5118 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 0.0010 - 10s/epoch - 17ms/step
#
# Epoch 13: LearningRateScheduler setting learning rate to 0.001.
# Epoch 13/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 10s - loss: 19.4943 - o1_loss: 0.3568 - o2_loss: 0.6932 - o3_loss: 0.6932 - o1_f1: 0.8531 - o2_f1: 0.0845 - o3_f1: 0.0834 - val_loss: 19.5055 - val_o1_loss: 0.3626 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5295 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 0.0010 - 10s/epoch - 18ms/step
#
# Epoch 14: LearningRateScheduler setting learning rate to 0.001.
# Epoch 14/100
# 230/230 [==============================] - 1s 5ms/step
# 587/587 - 9s - loss: 19.4892 - o1_loss: 0.3543 - o2_loss: 0.6932 - o3_loss: 0.6932 - o1_f1: 0.8556 - o2_f1: 0.0206 - o3_f1: 0.0194 - val_loss: 19.5002 - val_o1_loss: 0.3597 - val_o2_loss: 0.6932 - val_o3_loss: 0.6932 - val_o1_f1: 0.5203 - val_o2_f1: 0.6002 - val_o3_f1: 0.6002 - lr: 0.0010 - 9s/epoch - 16ms/step
#
# Epoch 15: LearningRateScheduler setting learning rate to 0.001.
# Epoch 15/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 10s - loss: 19.4855 - o1_loss: 0.3522 - o2_loss: 0.6932 - o3_loss: 0.6932 - o1_f1: 0.8580 - o2_f1: 0.1579 - o3_f1: 0.1509 - val_loss: 19.4951 - val_o1_loss: 0.3571 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5123 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.6002 - lr: 0.0010 - 10s/epoch - 16ms/step
#
# Epoch 16: LearningRateScheduler setting learning rate to 0.001.
# Epoch 16/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 10s - loss: 19.4823 - o1_loss: 0.3507 - o2_loss: 0.6932 - o3_loss: 0.6932 - o1_f1: 0.8604 - o2_f1: 0.1539 - o3_f1: 0.1400 - val_loss: 19.4923 - val_o1_loss: 0.3557 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5314 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 0.0010 - 10s/epoch - 16ms/step
#
# Epoch 17: LearningRateScheduler setting learning rate to 0.001.
# Epoch 17/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 10s - loss: 19.4785 - o1_loss: 0.3486 - o2_loss: 0.6932 - o3_loss: 0.6932 - o1_f1: 0.8614 - o2_f1: 0.1661 - o3_f1: 0.1572 - val_loss: 19.4894 - val_o1_loss: 0.3546 - val_o2_loss: 0.6932 - val_o3_loss: 0.6932 - val_o1_f1: 0.5284 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 0.0010 - 10s/epoch - 17ms/step
#
# Epoch 18: LearningRateScheduler setting learning rate to 0.001.
# Epoch 18/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 10s - loss: 19.4756 - o1_loss: 0.3473 - o2_loss: 0.6932 - o3_loss: 0.6932 - o1_f1: 0.8627 - o2_f1: 0.1374 - o3_f1: 0.1255 - val_loss: 19.4913 - val_o1_loss: 0.3556 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5255 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 0.0010 - 10s/epoch - 17ms/step
#
# Epoch 19: LearningRateScheduler setting learning rate to 0.001.
# Epoch 19/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 10s - loss: 19.4716 - o1_loss: 0.3456 - o2_loss: 0.6932 - o3_loss: 0.6932 - o1_f1: 0.8651 - o2_f1: 0.1060 - o3_f1: 0.1242 - val_loss: 19.4860 - val_o1_loss: 0.3528 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5343 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 0.0010 - 10s/epoch - 18ms/step
#
# Epoch 20: LearningRateScheduler setting learning rate to 0.001.
# Epoch 20/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 9s - loss: 19.4685 - o1_loss: 0.3438 - o2_loss: 0.6932 - o3_loss: 0.6932 - o1_f1: 0.8671 - o2_f1: 0.1323 - o3_f1: 0.1289 - val_loss: 19.4779 - val_o1_loss: 0.3489 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5302 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 0.0010 - 9s/epoch - 16ms/step
#
# Epoch 21: LearningRateScheduler setting learning rate to 0.001.
# Epoch 21/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 10s - loss: 19.4667 - o1_loss: 0.3428 - o2_loss: 0.6932 - o3_loss: 0.6932 - o1_f1: 0.8681 - o2_f1: 0.1293 - o3_f1: 0.1351 - val_loss: 19.4799 - val_o1_loss: 0.3491 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5295 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 0.0010 - 10s/epoch - 16ms/step
#
# Epoch 22: LearningRateScheduler setting learning rate to 0.001.
# Epoch 22/100
# 230/230 [==============================] - 1s 5ms/step
# 587/587 - 10s - loss: 19.4630 - o1_loss: 0.3411 - o2_loss: 0.6932 - o3_loss: 0.6932 - o1_f1: 0.8697 - o2_f1: 0.0051 - o3_f1: 0.0051 - val_loss: 19.4713 - val_o1_loss: 0.3456 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5314 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 0.0010 - 10s/epoch - 16ms/step
#
# Epoch 23: LearningRateScheduler setting learning rate to 0.001.
# Epoch 23/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 10s - loss: 19.4608 - o1_loss: 0.3399 - o2_loss: 0.6932 - o3_loss: 0.6932 - o1_f1: 0.8706 - o2_f1: 0.0428 - o3_f1: 0.0391 - val_loss: 19.4697 - val_o1_loss: 0.3445 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5249 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 0.0010 - 10s/epoch - 18ms/step
#
# Epoch 24: LearningRateScheduler setting learning rate to 0.001.
# Epoch 24/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 10s - loss: 19.4588 - o1_loss: 0.3389 - o2_loss: 0.6932 - o3_loss: 0.6932 - o1_f1: 0.8698 - o2_f1: 0.0749 - o3_f1: 0.0569 - val_loss: 19.4679 - val_o1_loss: 0.3437 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5234 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 0.0010 - 10s/epoch - 17ms/step
#
# Epoch 25: LearningRateScheduler setting learning rate to 0.001.
# Epoch 25/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 10s - loss: 19.4557 - o1_loss: 0.3371 - o2_loss: 0.6932 - o3_loss: 0.6932 - o1_f1: 0.8717 - o2_f1: 0.1330 - o3_f1: 0.0888 - val_loss: 19.4662 - val_o1_loss: 0.3430 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5373 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 0.0010 - 10s/epoch - 18ms/step
#
# Epoch 26: LearningRateScheduler setting learning rate to 0.001.
# Epoch 26/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 9s - loss: 19.4543 - o1_loss: 0.3367 - o2_loss: 0.6932 - o3_loss: 0.6932 - o1_f1: 0.8729 - o2_f1: 0.0982 - o3_f1: 0.1223 - val_loss: 19.4691 - val_o1_loss: 0.3442 - val_o2_loss: 0.6932 - val_o3_loss: 0.6932 - val_o1_f1: 0.5315 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 0.0010 - 9s/epoch - 16ms/step
#
# Epoch 27: LearningRateScheduler setting learning rate to 0.001.
# Epoch 27/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 10s - loss: 19.4518 - o1_loss: 0.3353 - o2_loss: 0.6932 - o3_loss: 0.6932 - o1_f1: 0.8731 - o2_f1: 0.1768 - o3_f1: 0.1821 - val_loss: 19.4606 - val_o1_loss: 0.3399 - val_o2_loss: 0.6932 - val_o3_loss: 0.6932 - val_o1_f1: 0.5331 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 0.0010 - 10s/epoch - 16ms/step
#
# Epoch 28: LearningRateScheduler setting learning rate to 0.001.
# Epoch 28/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 10s - loss: 19.4501 - o1_loss: 0.3344 - o2_loss: 0.6932 - o3_loss: 0.6932 - o1_f1: 0.8739 - o2_f1: 0.2166 - o3_f1: 0.0852 - val_loss: 19.4663 - val_o1_loss: 0.3426 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5155 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 0.0010 - 10s/epoch - 16ms/step
#
# Epoch 29: LearningRateScheduler setting learning rate to 0.001.
# Epoch 29/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 10s - loss: 19.4469 - o1_loss: 0.3328 - o2_loss: 0.6932 - o3_loss: 0.6932 - o1_f1: 0.8736 - o2_f1: 0.2888 - o3_f1: 0.2684 - val_loss: 19.4635 - val_o1_loss: 0.3412 - val_o2_loss: 0.6932 - val_o3_loss: 0.6932 - val_o1_f1: 0.5268 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 0.0010 - 10s/epoch - 17ms/step
#
# Epoch 30: LearningRateScheduler setting learning rate to 0.001.
# Epoch 30/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 10s - loss: 19.4457 - o1_loss: 0.3323 - o2_loss: 0.6932 - o3_loss: 0.6932 - o1_f1: 0.8745 - o2_f1: 0.0245 - o3_f1: 0.0067 - val_loss: 19.4583 - val_o1_loss: 0.3388 - val_o2_loss: 0.6932 - val_o3_loss: 0.6931 - val_o1_f1: 0.5383 - val_o2_f1: 0.6002 - val_o3_f1: 0.6002 - lr: 0.0010 - 10s/epoch - 18ms/step
#
# Epoch 31: LearningRateScheduler setting learning rate to 0.001.
# Epoch 31/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 10s - loss: 19.4432 - o1_loss: 0.3312 - o2_loss: 0.6932 - o3_loss: 0.6932 - o1_f1: 0.8756 - o2_f1: 0.2531 - o3_f1: 0.2599 - val_loss: 19.4570 - val_o1_loss: 0.3381 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5216 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 0.0010 - 10s/epoch - 18ms/step
#
# Epoch 32: LearningRateScheduler setting learning rate to 0.001.
# Epoch 32/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 9s - loss: 19.4415 - o1_loss: 0.3303 - o2_loss: 0.6932 - o3_loss: 0.6932 - o1_f1: 0.8760 - o2_f1: 0.1076 - o3_f1: 0.0485 - val_loss: 19.4647 - val_o1_loss: 0.3421 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5309 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 0.0010 - 9s/epoch - 16ms/step
#
# Epoch 33: LearningRateScheduler setting learning rate to 0.001.
# Epoch 33/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 10s - loss: 19.4411 - o1_loss: 0.3299 - o2_loss: 0.6932 - o3_loss: 0.6932 - o1_f1: 0.8766 - o2_f1: 0.1603 - o3_f1: 0.0810 - val_loss: 19.4535 - val_o1_loss: 0.3360 - val_o2_loss: 0.6932 - val_o3_loss: 0.6932 - val_o1_f1: 0.5393 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 0.0010 - 10s/epoch - 16ms/step
#
# Epoch 34: LearningRateScheduler setting learning rate to 0.001.
# Epoch 34/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 10s - loss: 19.4394 - o1_loss: 0.3290 - o2_loss: 0.6932 - o3_loss: 0.6932 - o1_f1: 0.8755 - o2_f1: 0.0646 - o3_f1: 0.0658 - val_loss: 19.4561 - val_o1_loss: 0.3371 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5196 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 0.0010 - 10s/epoch - 17ms/step
#
# Epoch 35: LearningRateScheduler setting learning rate to 0.001.
# Epoch 35/100
# 230/230 [==============================] - 1s 5ms/step
# 587/587 - 10s - loss: 19.4375 - o1_loss: 0.3283 - o2_loss: 0.6932 - o3_loss: 0.6932 - o1_f1: 0.8761 - o2_f1: 0.1923 - o3_f1: 0.2206 - val_loss: 19.4499 - val_o1_loss: 0.3346 - val_o2_loss: 0.6931 - val_o3_loss: 0.6932 - val_o1_f1: 0.5335 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 0.0010 - 10s/epoch - 17ms/step
#
# Epoch 36: LearningRateScheduler setting learning rate to 0.001.
# Epoch 36/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 10s - loss: 19.4364 - o1_loss: 0.3276 - o2_loss: 0.6932 - o3_loss: 0.6932 - o1_f1: 0.8779 - o2_f1: 0.0819 - o3_f1: 0.0822 - val_loss: 19.4478 - val_o1_loss: 0.3336 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5326 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 0.0010 - 10s/epoch - 18ms/step
#
# Epoch 37: LearningRateScheduler setting learning rate to 0.001.
# Epoch 37/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 10s - loss: 19.4345 - o1_loss: 0.3267 - o2_loss: 0.6932 - o3_loss: 0.6932 - o1_f1: 0.8777 - o2_f1: 0.1882 - o3_f1: 0.1847 - val_loss: 19.4456 - val_o1_loss: 0.3323 - val_o2_loss: 0.6932 - val_o3_loss: 0.6931 - val_o1_f1: 0.5352 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 0.0010 - 10s/epoch - 18ms/step
#
# Epoch 38: LearningRateScheduler setting learning rate to 0.001.
# Epoch 38/100
# 230/230 [==============================] - 1s 5ms/step
# 587/587 - 9s - loss: 19.4341 - o1_loss: 0.3264 - o2_loss: 0.6932 - o3_loss: 0.6932 - o1_f1: 0.8771 - o2_f1: 0.1511 - o3_f1: 0.1403 - val_loss: 19.4669 - val_o1_loss: 0.3431 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5280 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 0.0010 - 9s/epoch - 16ms/step
#
# Epoch 39: LearningRateScheduler setting learning rate to 0.001.
# Epoch 39/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 10s - loss: 19.4321 - o1_loss: 0.3254 - o2_loss: 0.6932 - o3_loss: 0.6932 - o1_f1: 0.8783 - o2_f1: 0.1029 - o3_f1: 0.1677 - val_loss: 19.4420 - val_o1_loss: 0.3305 - val_o2_loss: 0.6932 - val_o3_loss: 0.6932 - val_o1_f1: 0.5331 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 0.0010 - 10s/epoch - 16ms/step
#
# Epoch 40: LearningRateScheduler setting learning rate to 0.001.
# Epoch 40/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 10s - loss: 19.4308 - o1_loss: 0.3244 - o2_loss: 0.6932 - o3_loss: 0.6932 - o1_f1: 0.8778 - o2_f1: 0.1113 - o3_f1: 0.0477 - val_loss: 19.4412 - val_o1_loss: 0.3301 - val_o2_loss: 0.6931 - val_o3_loss: 0.6932 - val_o1_f1: 0.5329 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 0.0010 - 10s/epoch - 16ms/step
#
# Epoch 41: LearningRateScheduler setting learning rate to 0.001.
# Epoch 41/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 10s - loss: 19.4295 - o1_loss: 0.3241 - o2_loss: 0.6932 - o3_loss: 0.6932 - o1_f1: 0.8779 - o2_f1: 0.1789 - o3_f1: 0.1771 - val_loss: 19.4453 - val_o1_loss: 0.3321 - val_o2_loss: 0.6932 - val_o3_loss: 0.6932 - val_o1_f1: 0.5366 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 0.0010 - 10s/epoch - 17ms/step
#
# Epoch 42: LearningRateScheduler setting learning rate to 0.001.
# Epoch 42/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 10s - loss: 19.4291 - o1_loss: 0.3240 - o2_loss: 0.6932 - o3_loss: 0.6932 - o1_f1: 0.8788 - o2_f1: 0.1252 - o3_f1: 0.1163 - val_loss: 19.4402 - val_o1_loss: 0.3293 - val_o2_loss: 0.6932 - val_o3_loss: 0.6932 - val_o1_f1: 0.5373 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 0.0010 - 10s/epoch - 18ms/step
#
# Epoch 43: LearningRateScheduler setting learning rate to 0.001.
# Epoch 43/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 10s - loss: 19.4273 - o1_loss: 0.3228 - o2_loss: 0.6932 - o3_loss: 0.6932 - o1_f1: 0.8793 - o2_f1: 0.2102 - o3_f1: 0.1825 - val_loss: 19.4378 - val_o1_loss: 0.3281 - val_o2_loss: 0.6932 - val_o3_loss: 0.6931 - val_o1_f1: 0.5373 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 0.0010 - 10s/epoch - 17ms/step
#
# Epoch 44: LearningRateScheduler setting learning rate to 0.001.
# Epoch 44/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 9s - loss: 19.4265 - o1_loss: 0.3226 - o2_loss: 0.6932 - o3_loss: 0.6932 - o1_f1: 0.8789 - o2_f1: 0.0438 - o3_f1: 0.0078 - val_loss: 19.4367 - val_o1_loss: 0.3279 - val_o2_loss: 0.6932 - val_o3_loss: 0.6932 - val_o1_f1: 0.5361 - val_o2_f1: 0.6002 - val_o3_f1: 0.6002 - lr: 0.0010 - 9s/epoch - 16ms/step
#
# Epoch 45: LearningRateScheduler setting learning rate to 0.001.
# Epoch 45/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 10s - loss: 19.4258 - o1_loss: 0.3220 - o2_loss: 0.6932 - o3_loss: 0.6932 - o1_f1: 0.8791 - o2_f1: 0.3878 - o3_f1: 0.3094 - val_loss: 19.4394 - val_o1_loss: 0.3294 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5384 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 0.0010 - 10s/epoch - 16ms/step
#
# Epoch 46: LearningRateScheduler setting learning rate to 0.001.
# Epoch 46/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 10s - loss: 19.4265 - o1_loss: 0.3225 - o2_loss: 0.6932 - o3_loss: 0.6932 - o1_f1: 0.8788 - o2_f1: 0.0835 - o3_f1: 0.0633 - val_loss: 19.4357 - val_o1_loss: 0.3271 - val_o2_loss: 0.6932 - val_o3_loss: 0.6932 - val_o1_f1: 0.5373 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 0.0010 - 10s/epoch - 16ms/step
#
# Epoch 47: LearningRateScheduler setting learning rate to 0.001.
# Epoch 47/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 10s - loss: 19.4244 - o1_loss: 0.3212 - o2_loss: 0.6932 - o3_loss: 0.6932 - o1_f1: 0.8791 - o2_f1: 0.0883 - o3_f1: 0.0858 - val_loss: 19.4333 - val_o1_loss: 0.3262 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5352 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 0.0010 - 10s/epoch - 18ms/step
#
# Epoch 48: LearningRateScheduler setting learning rate to 0.001.
# Epoch 48/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 10s - loss: 19.4219 - o1_loss: 0.3203 - o2_loss: 0.6932 - o3_loss: 0.6932 - o1_f1: 0.8793 - o2_f1: 0.1827 - o3_f1: 0.0994 - val_loss: 19.4321 - val_o1_loss: 0.3257 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5373 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 0.0010 - 10s/epoch - 18ms/step
#
# Epoch 49: LearningRateScheduler setting learning rate to 0.001.
# Epoch 49/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 10s - loss: 19.4216 - o1_loss: 0.3201 - o2_loss: 0.6932 - o3_loss: 0.6932 - o1_f1: 0.8790 - o2_f1: 0.1013 - o3_f1: 0.0563 - val_loss: 19.4338 - val_o1_loss: 0.3264 - val_o2_loss: 0.6932 - val_o3_loss: 0.6931 - val_o1_f1: 0.5355 - val_o2_f1: 0.6002 - val_o3_f1: 0.6002 - lr: 0.0010 - 10s/epoch - 18ms/step
#
# Epoch 50: LearningRateScheduler setting learning rate to 0.00025.
# Epoch 50/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 9s - loss: 19.4185 - o1_loss: 0.3188 - o2_loss: 0.6932 - o3_loss: 0.6932 - o1_f1: 0.8808 - o2_f1: 0.1154 - o3_f1: 0.0693 - val_loss: 19.4315 - val_o1_loss: 0.3254 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5361 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 2.5000e-04 - 9s/epoch - 16ms/step
#
# Epoch 51: LearningRateScheduler setting learning rate to 0.00025.
# Epoch 51/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 10s - loss: 19.4181 - o1_loss: 0.3186 - o2_loss: 0.6931 - o3_loss: 0.6931 - o1_f1: 0.8810 - o2_f1: 0.2963 - o3_f1: 0.2657 - val_loss: 19.4308 - val_o1_loss: 0.3251 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5361 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 2.5000e-04 - 10s/epoch - 16ms/step
#
# Epoch 52: LearningRateScheduler setting learning rate to 0.00025.
# Epoch 52/100
# 230/230 [==============================] - 1s 5ms/step
# 587/587 - 10s - loss: 19.4180 - o1_loss: 0.3186 - o2_loss: 0.6931 - o3_loss: 0.6931 - o1_f1: 0.8810 - o2_f1: 0.0000e+00 - o3_f1: 0.0000e+00 - val_loss: 19.4306 - val_o1_loss: 0.3249 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5373 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 2.5000e-04 - 10s/epoch - 16ms/step
#
# Epoch 53: LearningRateScheduler setting learning rate to 0.00025.
# Epoch 53/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 11s - loss: 19.4179 - o1_loss: 0.3185 - o2_loss: 0.6931 - o3_loss: 0.6931 - o1_f1: 0.8812 - o2_f1: 0.0000e+00 - o3_f1: 0.0000e+00 - val_loss: 19.4324 - val_o1_loss: 0.3259 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5352 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 2.5000e-04 - 11s/epoch - 19ms/step
#
# Epoch 54: LearningRateScheduler setting learning rate to 0.00025.
# Epoch 54/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 12s - loss: 19.4175 - o1_loss: 0.3183 - o2_loss: 0.6932 - o3_loss: 0.6931 - o1_f1: 0.8809 - o2_f1: 0.0000e+00 - o3_f1: 0.0000e+00 - val_loss: 19.4301 - val_o1_loss: 0.3247 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5373 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 2.5000e-04 - 12s/epoch - 20ms/step
#
# Epoch 55: LearningRateScheduler setting learning rate to 0.00025.
# Epoch 55/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 10s - loss: 19.4175 - o1_loss: 0.3183 - o2_loss: 0.6931 - o3_loss: 0.6931 - o1_f1: 0.8808 - o2_f1: 0.0000e+00 - o3_f1: 0.0000e+00 - val_loss: 19.4307 - val_o1_loss: 0.3250 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5373 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 2.5000e-04 - 10s/epoch - 18ms/step
#
# Epoch 56: LearningRateScheduler setting learning rate to 0.00025.
# Epoch 56/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 9s - loss: 19.4175 - o1_loss: 0.3183 - o2_loss: 0.6931 - o3_loss: 0.6931 - o1_f1: 0.8808 - o2_f1: 0.0000e+00 - o3_f1: 0.0000e+00 - val_loss: 19.4307 - val_o1_loss: 0.3250 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5373 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 2.5000e-04 - 9s/epoch - 16ms/step
#
# Epoch 57: LearningRateScheduler setting learning rate to 0.00025.
# Epoch 57/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 10s - loss: 19.4167 - o1_loss: 0.3180 - o2_loss: 0.6931 - o3_loss: 0.6931 - o1_f1: 0.8812 - o2_f1: 0.0000e+00 - o3_f1: 0.0000e+00 - val_loss: 19.4296 - val_o1_loss: 0.3244 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5361 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 2.5000e-04 - 10s/epoch - 16ms/step
#
# Epoch 58: LearningRateScheduler setting learning rate to 0.00025.
# Epoch 58/100
# 230/230 [==============================] - 1s 5ms/step
# 587/587 - 9s - loss: 19.4166 - o1_loss: 0.3179 - o2_loss: 0.6931 - o3_loss: 0.6931 - o1_f1: 0.8805 - o2_f1: 0.0000e+00 - o3_f1: 0.0000e+00 - val_loss: 19.4305 - val_o1_loss: 0.3249 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5373 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 2.5000e-04 - 9s/epoch - 16ms/step
#
# Epoch 59: LearningRateScheduler setting learning rate to 0.00025.
# Epoch 59/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 10s - loss: 19.4167 - o1_loss: 0.3179 - o2_loss: 0.6931 - o3_loss: 0.6931 - o1_f1: 0.8802 - o2_f1: 0.0000e+00 - o3_f1: 0.0000e+00 - val_loss: 19.4290 - val_o1_loss: 0.3242 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5373 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 2.5000e-04 - 10s/epoch - 18ms/step
#
# Epoch 60: LearningRateScheduler setting learning rate to 0.00025.
# Epoch 60/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 10s - loss: 19.4164 - o1_loss: 0.3178 - o2_loss: 0.6931 - o3_loss: 0.6931 - o1_f1: 0.8815 - o2_f1: 0.0000e+00 - o3_f1: 0.0000e+00 - val_loss: 19.4305 - val_o1_loss: 0.3249 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5352 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 2.5000e-04 - 10s/epoch - 18ms/step
#
# Epoch 61: LearningRateScheduler setting learning rate to 0.00025.
# Epoch 61/100
# 230/230 [==============================] - 4s 17ms/step
# 587/587 - 20s - loss: 19.4159 - o1_loss: 0.3176 - o2_loss: 0.6931 - o3_loss: 0.6931 - o1_f1: 0.8815 - o2_f1: 0.0000e+00 - o3_f1: 0.0000e+00 - val_loss: 19.4305 - val_o1_loss: 0.3249 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5405 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 2.5000e-04 - 20s/epoch - 33ms/step
#
# Epoch 62: LearningRateScheduler setting learning rate to 0.00025.
# Epoch 62/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 10s - loss: 19.4159 - o1_loss: 0.3175 - o2_loss: 0.6931 - o3_loss: 0.6931 - o1_f1: 0.8814 - o2_f1: 0.0000e+00 - o3_f1: 0.0000e+00 - val_loss: 19.4308 - val_o1_loss: 0.3251 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5373 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 2.5000e-04 - 10s/epoch - 17ms/step
#
# Epoch 63: LearningRateScheduler setting learning rate to 0.00025.
# Epoch 63/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 10s - loss: 19.4158 - o1_loss: 0.3175 - o2_loss: 0.6931 - o3_loss: 0.6931 - o1_f1: 0.8813 - o2_f1: 0.0000e+00 - o3_f1: 0.0000e+00 - val_loss: 19.4286 - val_o1_loss: 0.3240 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5373 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 2.5000e-04 - 10s/epoch - 16ms/step
#
# Epoch 64: LearningRateScheduler setting learning rate to 0.00025.
# Epoch 64/100
# 230/230 [==============================] - 1s 5ms/step
# 587/587 - 10s - loss: 19.4152 - o1_loss: 0.3172 - o2_loss: 0.6931 - o3_loss: 0.6931 - o1_f1: 0.8804 - o2_f1: 0.0000e+00 - o3_f1: 0.0000e+00 - val_loss: 19.4295 - val_o1_loss: 0.3244 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5373 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 2.5000e-04 - 10s/epoch - 16ms/step
#
# Epoch 65: LearningRateScheduler setting learning rate to 0.00025.
# Epoch 65/100
# 230/230 [==============================] - 1s 5ms/step
# 587/587 - 10s - loss: 19.4151 - o1_loss: 0.3172 - o2_loss: 0.6931 - o3_loss: 0.6931 - o1_f1: 0.8809 - o2_f1: 0.0000e+00 - o3_f1: 0.0000e+00 - val_loss: 19.4282 - val_o1_loss: 0.3238 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5373 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 2.5000e-04 - 10s/epoch - 17ms/step
#
# Epoch 66: LearningRateScheduler setting learning rate to 0.00025.
# Epoch 66/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 10s - loss: 19.4149 - o1_loss: 0.3170 - o2_loss: 0.6931 - o3_loss: 0.6931 - o1_f1: 0.8806 - o2_f1: 0.0000e+00 - o3_f1: 0.0000e+00 - val_loss: 19.4288 - val_o1_loss: 0.3239 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5405 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 2.5000e-04 - 10s/epoch - 18ms/step
#
# Epoch 67: LearningRateScheduler setting learning rate to 0.00025.
# Epoch 67/100
# 230/230 [==============================] - 4s 14ms/step
# 587/587 - 28s - loss: 19.4150 - o1_loss: 0.3170 - o2_loss: 0.6932 - o3_loss: 0.6931 - o1_f1: 0.8815 - o2_f1: 0.0000e+00 - o3_f1: 0.0000e+00 - val_loss: 19.4274 - val_o1_loss: 0.3234 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5373 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 2.5000e-04 - 28s/epoch - 48ms/step
#
# Epoch 68: LearningRateScheduler setting learning rate to 0.00025.
# Epoch 68/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 10s - loss: 19.4147 - o1_loss: 0.3170 - o2_loss: 0.6931 - o3_loss: 0.6931 - o1_f1: 0.8810 - o2_f1: 0.0000e+00 - o3_f1: 0.0000e+00 - val_loss: 19.4302 - val_o1_loss: 0.3248 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5405 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 2.5000e-04 - 10s/epoch - 17ms/step
#
# Epoch 69: LearningRateScheduler setting learning rate to 0.00025.
# Epoch 69/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 10s - loss: 19.4145 - o1_loss: 0.3168 - o2_loss: 0.6932 - o3_loss: 0.6931 - o1_f1: 0.8809 - o2_f1: 0.0413 - o3_f1: 0.0000e+00 - val_loss: 19.4273 - val_o1_loss: 0.3233 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5373 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 2.5000e-04 - 10s/epoch - 16ms/step
#
# Epoch 70: LearningRateScheduler setting learning rate to 0.00025.
# Epoch 70/100
# 230/230 [==============================] - 1s 5ms/step
# 587/587 - 10s - loss: 19.4140 - o1_loss: 0.3166 - o2_loss: 0.6931 - o3_loss: 0.6931 - o1_f1: 0.8811 - o2_f1: 0.0000e+00 - o3_f1: 0.0000e+00 - val_loss: 19.4270 - val_o1_loss: 0.3231 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5373 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 2.5000e-04 - 10s/epoch - 16ms/step
#
# Epoch 71: LearningRateScheduler setting learning rate to 0.00025.
# Epoch 71/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 10s - loss: 19.4144 - o1_loss: 0.3168 - o2_loss: 0.6931 - o3_loss: 0.6931 - o1_f1: 0.8808 - o2_f1: 0.0000e+00 - o3_f1: 0.0000e+00 - val_loss: 19.4267 - val_o1_loss: 0.3230 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5373 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 2.5000e-04 - 10s/epoch - 18ms/step
#
# Epoch 72: LearningRateScheduler setting learning rate to 0.00025.
# Epoch 72/100
# 230/230 [==============================] - 4s 13ms/step
# 587/587 - 28s - loss: 19.4136 - o1_loss: 0.3164 - o2_loss: 0.6931 - o3_loss: 0.6931 - o1_f1: 0.8815 - o2_f1: 0.0000e+00 - o3_f1: 0.0000e+00 - val_loss: 19.4289 - val_o1_loss: 0.3241 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5361 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 2.5000e-04 - 28s/epoch - 47ms/step
#
# Epoch 73: LearningRateScheduler setting learning rate to 0.00025.
# Epoch 73/100
# 230/230 [==============================] - 2s 7ms/step
# 587/587 - 30s - loss: 19.4139 - o1_loss: 0.3165 - o2_loss: 0.6931 - o3_loss: 0.6931 - o1_f1: 0.8815 - o2_f1: 0.0000e+00 - o3_f1: 0.0000e+00 - val_loss: 19.4291 - val_o1_loss: 0.3241 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5339 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 2.5000e-04 - 30s/epoch - 51ms/step
#
# Epoch 74: LearningRateScheduler setting learning rate to 0.00025.
# Epoch 74/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 10s - loss: 19.4136 - o1_loss: 0.3164 - o2_loss: 0.6931 - o3_loss: 0.6931 - o1_f1: 0.8809 - o2_f1: 0.0000e+00 - o3_f1: 0.0000e+00 - val_loss: 19.4273 - val_o1_loss: 0.3233 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5405 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 2.5000e-04 - 10s/epoch - 16ms/step
#
# Epoch 75: LearningRateScheduler setting learning rate to 0.00025.
# Epoch 75/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 10s - loss: 19.4134 - o1_loss: 0.3163 - o2_loss: 0.6931 - o3_loss: 0.6931 - o1_f1: 0.8812 - o2_f1: 0.0000e+00 - o3_f1: 0.0000e+00 - val_loss: 19.4264 - val_o1_loss: 0.3229 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5361 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 2.5000e-04 - 10s/epoch - 16ms/step
#
# Epoch 76: LearningRateScheduler setting learning rate to 0.00025.
# Epoch 76/100
# ...
#
# Epoch 87: LearningRateScheduler setting learning rate to 0.00025.
# Epoch 87/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 9s - loss: 19.4111 - o1_loss: 0.3151 - o2_loss: 0.6931 - o3_loss: 0.6931 - o1_f1: 0.8820 - o2_f1: 0.0000e+00 - o3_f1: 0.0000e+00 - val_loss: 19.4248 - val_o1_loss: 0.3221 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5373 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 2.5000e-04 - 9s/epoch - 16ms/step
#
# Epoch 88: LearningRateScheduler setting learning rate to 0.00025.
# Epoch 88/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 10s - loss: 19.4112 - o1_loss: 0.3152 - o2_loss: 0.6932 - o3_loss: 0.6931 - o1_f1: 0.8821 - o2_f1: 0.0113 - o3_f1: 0.0000e+00 - val_loss: 19.4262 - val_o1_loss: 0.3227 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5404 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 2.5000e-04 - 10s/epoch - 16ms/step
#
# Epoch 89: LearningRateScheduler setting learning rate to 0.00025.
# Epoch 89/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 10s - loss: 19.4110 - o1_loss: 0.3150 - o2_loss: 0.6932 - o3_loss: 0.6931 - o1_f1: 0.8817 - o2_f1: 0.0000e+00 - o3_f1: 0.0000e+00 - val_loss: 19.4262 - val_o1_loss: 0.3227 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5383 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 2.5000e-04 - 10s/epoch - 18ms/step
#
# Epoch 90: LearningRateScheduler setting learning rate to 0.00025.
# Epoch 90/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 10s - loss: 19.4107 - o1_loss: 0.3149 - o2_loss: 0.6932 - o3_loss: 0.6931 - o1_f1: 0.8821 - o2_f1: 0.0000e+00 - o3_f1: 0.0000e+00 - val_loss: 19.4235 - val_o1_loss: 0.3214 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5373 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 2.5000e-04 - 10s/epoch - 17ms/step
#
# Epoch 91: LearningRateScheduler setting learning rate to 0.00025.
# Epoch 91/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 10s - loss: 19.4107 - o1_loss: 0.3149 - o2_loss: 0.6931 - o3_loss: 0.6931 - o1_f1: 0.8822 - o2_f1: 0.0000e+00 - o3_f1: 0.0000e+00 - val_loss: 19.4235 - val_o1_loss: 0.3214 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5373 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 2.5000e-04 - 10s/epoch - 17ms/step
#
# Epoch 92: LearningRateScheduler setting learning rate to 0.00025.
# Epoch 92/100
# 230/230 [==============================] - 1s 5ms/step
# 587/587 - 10s - loss: 19.4107 - o1_loss: 0.3149 - o2_loss: 0.6931 - o3_loss: 0.6931 - o1_f1: 0.8813 - o2_f1: 0.0000e+00 - o3_f1: 0.0000e+00 - val_loss: 19.4229 - val_o1_loss: 0.3211 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5373 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 2.5000e-04 - 10s/epoch - 18ms/step
#
# Epoch 93: LearningRateScheduler setting learning rate to 0.00025.
# Epoch 93/100
# 230/230 [==============================] - 1s 5ms/step
# 587/587 - 9s - loss: 19.4102 - o1_loss: 0.3147 - o2_loss: 0.6931 - o3_loss: 0.6931 - o1_f1: 0.8813 - o2_f1: 0.0000e+00 - o3_f1: 0.0000e+00 - val_loss: 19.4231 - val_o1_loss: 0.3212 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5373 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 2.5000e-04 - 9s/epoch - 16ms/step
#
# Epoch 94: LearningRateScheduler setting learning rate to 0.00025.
# Epoch 94/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 10s - loss: 19.4101 - o1_loss: 0.3146 - o2_loss: 0.6931 - o3_loss: 0.6931 - o1_f1: 0.8814 - o2_f1: 0.0000e+00 - o3_f1: 0.0000e+00 - val_loss: 19.4244 - val_o1_loss: 0.3219 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5404 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 2.5000e-04 - 10s/epoch - 16ms/step
#
# Epoch 95: LearningRateScheduler setting learning rate to 0.00025.
# Epoch 95/100
# 230/230 [==============================] - 1s 5ms/step
# 587/587 - 10s - loss: 19.4098 - o1_loss: 0.3145 - o2_loss: 0.6931 - o3_loss: 0.6931 - o1_f1: 0.8813 - o2_f1: 0.0000e+00 - o3_f1: 0.0000e+00 - val_loss: 19.4229 - val_o1_loss: 0.3211 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5361 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 2.5000e-04 - 10s/epoch - 17ms/step
#
# Epoch 96: LearningRateScheduler setting learning rate to 0.00025.
# Epoch 96/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 10s - loss: 19.4101 - o1_loss: 0.3146 - o2_loss: 0.6931 - o3_loss: 0.6931 - o1_f1: 0.8825 - o2_f1: 0.0000e+00 - o3_f1: 0.0000e+00 - val_loss: 19.4229 - val_o1_loss: 0.3211 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5373 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 2.5000e-04 - 10s/epoch - 17ms/step
#
# Epoch 97: LearningRateScheduler setting learning rate to 0.00025.
# Epoch 97/100
# 230/230 [==============================] - 1s 5ms/step
# 587/587 - 10s - loss: 19.4096 - o1_loss: 0.3144 - o2_loss: 0.6931 - o3_loss: 0.6931 - o1_f1: 0.8823 - o2_f1: 0.0000e+00 - o3_f1: 0.0000e+00 - val_loss: 19.4317 - val_o1_loss: 0.3255 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5350 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 2.5000e-04 - 10s/epoch - 17ms/step
#
# Epoch 98: LearningRateScheduler setting learning rate to 0.00025.
# Epoch 98/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 10s - loss: 19.4100 - o1_loss: 0.3144 - o2_loss: 0.6932 - o3_loss: 0.6932 - o1_f1: 0.8813 - o2_f1: 0.0000e+00 - o3_f1: 0.0000e+00 - val_loss: 19.4227 - val_o1_loss: 0.3210 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5361 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 2.5000e-04 - 10s/epoch - 18ms/step
#
# Epoch 99: LearningRateScheduler setting learning rate to 0.00025.
# Epoch 99/100
# 230/230 [==============================] - 1s 6ms/step
# 587/587 - 9s - loss: 19.4094 - o1_loss: 0.3143 - o2_loss: 0.6932 - o3_loss: 0.6931 - o1_f1: 0.8822 - o2_f1: 0.0178 - o3_f1: 0.0000e+00 - val_loss: 19.4223 - val_o1_loss: 0.3208 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5373 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 2.5000e-04 - 9s/epoch - 16ms/step
#
# Epoch 100: LearningRateScheduler setting learning rate to 6.25e-05.
# Epoch 100/100
# 230/230 [==============================] - 1s 5ms/step
# 587/587 - 9s - loss: 19.4084 - o1_loss: 0.3139 - o2_loss: 0.6931 - o3_loss: 0.6931 - o1_f1: 0.8815 - o2_f1: 0.0000e+00 - o3_f1: 0.0000e+00 - val_loss: 19.4222 - val_o1_loss: 0.3208 - val_o2_loss: 0.6931 - val_o3_loss: 0.6931 - val_o1_f1: 0.5405 - val_o2_f1: 0.0000e+00 - val_o3_f1: 0.0000e+00 - lr: 6.2500e-05 - 9s/epoch - 16ms/step
# ['val_o1_loss', 'val_o2_loss', 'val_o3_loss']
# ['o1_loss', 'o2_loss', 'o3_loss']
# ['lr', 'o1_f1', 'o2_f1', 'o3_f1', 'val_o1_f1', 'val_o2_f1', 'val_o3_f1']
# 2023-11-29 18:58:59.473769: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 14449093896 exceeds 10% of free system memory.
# 1834/1834 [==============================] - 10s 6ms/step
# (58677, 1)
# [0.1  0.11 0.12 0.13 0.14 0.15 0.16 0.17 0.18 0.19 0.2  0.21 0.22 0.23
#  0.24 0.25 0.26 0.27 0.28 0.29 0.3  0.31 0.32 0.33 0.34 0.35 0.36 0.37
#  0.38 0.39 0.4  0.41 0.42 0.43 0.44 0.45 0.46 0.47 0.48 0.49 0.5  0.51
#  0.52 0.53 0.54 0.55 0.56 0.57 0.58 0.59 0.6  0.61 0.62 0.63 0.64 0.65
#  0.66 0.67 0.68 0.69 0.7  0.71 0.72 0.73 0.74 0.75 0.76 0.77 0.78 0.79
#  0.8  0.81 0.82 0.83 0.84 0.85 0.86 0.87 0.88 0.89]
# /SOFTWARE/anaconda/[/home/DATA]/envs/Taiji-env/Sally_PNET_py3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /SOFTWARE/anaconda/[/home/DATA]/envs/Taiji-env/Sally_PNET_py3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /SOFTWARE/anaconda/[/home/DATA]/envs/Taiji-env/Sally_PNET_py3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /SOFTWARE/anaconda/[/home/DATA]/envs/Taiji-env/Sally_PNET_py3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /SOFTWARE/anaconda/[/home/DATA]/envs/Taiji-env/Sally_PNET_py3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /SOFTWARE/anaconda/[/home/DATA]/envs/Taiji-env/Sally_PNET_py3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /SOFTWARE/anaconda/[/home/DATA]/envs/Taiji-env/Sally_PNET_py3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /SOFTWARE/anaconda/[/home/DATA]/envs/Taiji-env/Sally_PNET_py3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /SOFTWARE/anaconda/[/home/DATA]/envs/Taiji-env/Sally_PNET_py3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /SOFTWARE/anaconda/[/home/DATA]/envs/Taiji-env/Sally_PNET_py3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /SOFTWARE/anaconda/[/home/DATA]/envs/Taiji-env/Sally_PNET_py3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /SOFTWARE/anaconda/[/home/DATA]/envs/Taiji-env/Sally_PNET_py3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /SOFTWARE/anaconda/[/home/DATA]/envs/Taiji-env/Sally_PNET_py3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /SOFTWARE/anaconda/[/home/DATA]/envs/Taiji-env/Sally_PNET_py3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /SOFTWARE/anaconda/[/home/DATA]/envs/Taiji-env/Sally_PNET_py3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /SOFTWARE/anaconda/[/home/DATA]/envs/Taiji-env/Sally_PNET_py3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /SOFTWARE/anaconda/[/home/DATA]/envs/Taiji-env/Sally_PNET_py3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /SOFTWARE/anaconda/[/home/DATA]/envs/Taiji-env/Sally_PNET_py3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /SOFTWARE/anaconda/[/home/DATA]/envs/Taiji-env/Sally_PNET_py3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /SOFTWARE/anaconda/[/home/DATA]/envs/Taiji-env/Sally_PNET_py3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /SOFTWARE/anaconda/[/home/DATA]/envs/Taiji-env/Sally_PNET_py3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /SOFTWARE/anaconda/[/home/DATA]/envs/Taiji-env/Sally_PNET_py3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /SOFTWARE/anaconda/[/home/DATA]/envs/Taiji-env/Sally_PNET_py3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#     accuracy  precision        f1  recall    th
# 0   0.498253   0.498253  0.665112     1.0  0.10
# 1   0.498253   0.498253  0.665112     1.0  0.11
# 2   0.498253   0.498253  0.665112     1.0  0.12
# 3   0.498253   0.498253  0.665112     1.0  0.13
# 4   0.498253   0.498253  0.665112     1.0  0.14
# ..       ...        ...       ...     ...   ...
# 75  0.501747   0.000000  0.000000     0.0  0.85
# 76  0.501747   0.000000  0.000000     0.0  0.86
# 77  0.501747   0.000000  0.000000     0.0  0.87
# 78  0.501747   0.000000  0.000000     0.0  0.88
# 79  0.501747   0.000000  0.000000     0.0  0.89
#
# [80 rows x 5 columns]
# prediction threshold 0.4999999999999998

# %%
y_pred_test = model.predict(x_test_)

from sklearn import metrics
from sklearn.metrics import accuracy_score

import matplotlib.pyplot as plt
 
def evaluate_classification_binary(y_test, y_pred, y_pred_score=None):
    accuracy = accuracy_score(y_test, y_pred)
    if y_pred_score is None:
        fpr, tpr, thresholds = metrics.roc_curve(y_test, y_pred, pos_label=1)
    else:
        fpr, tpr, thresholds = metrics.roc_curve(y_test, y_pred_score, pos_label=1)
    auc = metrics.auc(fpr, tpr)
    f1 = metrics.f1_score(y_test, y_pred)
    precision = metrics.precision_score(y_test, y_pred)
    recall = metrics.recall_score(y_test, y_pred)
    logging.info(metrics.classification_report(y_test, y_pred))
    from sklearn.metrics import average_precision_score
    aupr = average_precision_score(y_test, y_pred_score)
    score = {}
    score['accuracy'] = accuracy
    score['precision'] = precision
    score['auc'] = auc
    score['f1'] = f1
    score['aupr'] = aupr
    score['recall'] = recall

    # plot auc curve
    plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {auc:.2f})')
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic (ROC) Curve')
    plt.legend(loc='lower right')

    # Save the ROC plot
    plt.savefig('roc_curve.png')

    # Show the ROC plot
    plt.show()

    return score

if hasattr(model, 'predict_proba'):
    y_pred_test_scores = model.predict_proba(x_test_)[:, 1]
else:
    y_pred_test_scores = y_pred_test

test_score = evaluate_classification_binary(y_test_, y_pred_test, y_pred_test_scores)

logging.info('Test score {}'.format(test_score))
# Out:
# 230/230 [==============================] - 1s 5ms/step
# (7335, 1)
# 230/230 [==============================] - 1s 5ms/step
# (7335, 1)
# (7335, 2)
#               precision    recall  f1-score   support
#
#            0       0.84      0.99      0.91      3666
#            1       0.99      0.81      0.89      3669
#
#     accuracy                           0.90      7335
#    macro avg       0.91      0.90      0.90      7335
# weighted avg       0.91      0.90      0.90      7335
# Test score {'accuracy': 0.9004771642808452, 'precision': 0.9906510851419031, 'auc': 0.9029475663232905, 'f1': 0.8904561824729892, 'aupr': 0.9189341548199839, 'recall': 0.8086672117743254}

# %%
# !python analysis/run_it_all.py

model_name = 'P-net'

# save prediction data for plot generation

def save_prediction(info, y_pred, y_pred_scores, y_test, model_name, training=False):

        if training:
            file_name = join(model_name + '_training.csv')
        else:
            file_name = join(model_name + '_testing.csv')
        info = pd.DataFrame(index=info)
        print(('info', info))
        print(y_test)
        info['pred'] = y_pred
        info['pred_scores'] = y_pred_scores

        # survival case
        # https://docs.scipy.org/doc/numpy/user/basics.rec.html
        if y_test.dtype.fields is not None:
            fields = y_test.dtype.fields
            for f in fields:
                info['y_{}'.format(f)] = y_test[f]
        else:
            info['y'] = y_test
        info.to_csv(file_name)

save_prediction(info_t, y_pred_test, y_pred_test_scores, y_test_, model_name)

# save model

filename = '/PROJECTS/Sally/PNET_py3_enh_gene/_logs/enh_vs_genes/log/fs/P-net.h5'

# filename = join(log_dir, 'fs')
# filename = join(filename, model_name + '.h5')
# # if not exists(filename.strip()):
# #     makedirs(filename)

# save model weights 

w_filename = '/PROJECTS/Sally/PNET_py3_enh_gene/_logs/enh_vs_genes/log/fs/P-net_weights.h5'

# model.save_model(w_filename)

# load model 


#load model weights

# model = model.load_model(w_filename)
# Out:
# ('info', Empty DataFrame
# Columns: []
# Index: [19, 138, 170, 183, 219, 274, 409, 909, 959, 1023, 1042, 1056, 1070, 1092, 1308, 1320, 1543, 1559, 1861, 1924, 2063, 2126, 2267, 2499, 2585, 2593, 2600, 2604, 2605, 2607, 2611, 2672, 3102, 3160, 3225, 3375, 3386, 3390, 3391, 3396, 3417, 3418, 3422, 3438, 3462, 3994, 3995, 3997, 4005, 4008, 4171, 4318, 4352, 4457, 4461, 4465, 4490, 4550, 4716, 4739, 4791, 4942, 4944, 5032, 5121, 5137, 5174, 5262, 5338, 5822, 6246, 6289, 6380, 6409, 6608, 6909, 7083, 7100, 7108, 7299, 7388, 7545, 7572, 7672, 7787, 7899, 7918, 8054, 8482, 9176, 9297, 9330, 9384, 9575, 9725, 9755, 9860, 9899, 9911, 9926, ...]
#
# [7335 rows x 0 columns])
# NA
# 19        0
# 138       0
# 170       0
# 183       0
# 219       0
#          ..
# 619048    1
# 619051    0
# 619066    0
# 619068    1
# 619077    0
# Name: response, Length: 7335, dtype: int64

# %%
# shap implementation

import shap   
from tensorflow.keras.models import load_model, model_from_json

sample = x_test_[1:11]

# sample_output = model.predict(sample)

# # Find the indices where the value is 1
# indices_of_ones = np.where(sample_output == 1)[0]

# # Print the indices
# print("Indices of '1':", indices_of_ones)

# print('sample_output:', sample_output)

from config_path import INTERACTIONS_PATH

gene_names = join(INTERACTIONS_PATH, 'enh_vs_genes_selected_genes.csv')

# Read the CSV file
df = pd.read_csv(gene_names)

# Extract gene names into a list
genes_list = df['genes'].tolist()

explainer = shap.Explainer(model, x_test_)
shap_values = explainer.shap_values(sample)
shap.summary_plot(shap_values, sample, feature_names=genes_list)
# Out:
# 52/52 [==============================] - 0s 5ms/step
# (1662, 1)
# 52/52 [==============================] - 0s 5ms/step
# (1662, 1)
# 52/52 [==============================] - 0s 5ms/step
# (1662, 1)

# %%
# shap.plots.force(explainer.expected_value, shap_values)
# Out:
# Int64Index([    19,    138,    170,    183,    219,    274,    409,    909,
#                959,   1023,
#             ...
#             612524, 612732, 612836, 612921, 612995, 619048, 619051, 619066,
#             619068, 619077],
#            dtype='int64', name='NA', length=7335)
